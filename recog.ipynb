# %%
#Entity Details

import requests
# URL and headers
url = 'https://api.startupindia.gov.in/sih/api/auth/dpiit/services/application/save'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Content-Type': 'application/json',
    'X-Auth-Token': 'eyJhbGciOiJIUzUxMiIsInppcCI6IkRFRiJ9.eNp8jjsOwjAQRO-yNYoSx3HsVJyAhhJRrJ2NMApx5A9Cirg7i6CgopzZN6u3wTV7GEBJ2zVG9SRt7aTUirTqlSDYAZaRgUOIN5w5pmI53jEmrHwSzd7ekqMKXeUXPnvMMDRKG63attc7oMf6KUytundREkUYNliLnX26EH_PsRBPl7GkHD0lGE7QTVI76iaBxlqeunHCpm9rOLMDuRziH8yINzYHh9mHhX2_mPnBzGTFyMYxzMTEMWPMZYXn8wUAAP__.gnPJMnCi3DkdKbNf7ggZa7ZkexIWYNG6M58g-LvRBeLYetV2oAzpAAFRk70GM9hCIDk7V0cXsfP_7W3CTB3aVg'
}

# Payload data
payload = {
    "incorporationNumber": "U62092MP2023PTC065665",
    "startupEntity": {
        "startupNatureOfEntity": {"id": "5f48ce5f2a9bb065cdfa185b"},
        "startupIndustry": {"id": "5f48ce5f2a9bb065cdfa1730"},
        "startupSection": {"id": "5f48ce5f2a9bb065cdfa1791"},
        "startupServices": [{"id": "5f48ce5f2a9bb065cdfa1856"}],
        "name": "HAXSPLOIT SECURITY SERVICES PRIVATE LIMITED",
        "incorporationDate": "2023-05-09",
        "panNumber": "AALCB0603L"
    },
    "recognitionDetailType": "ENTITY",
    "status": "DRAFT"
}

# Make the POST request
response = requests.post(url, headers=headers, json=payload)

# Check the response
if response.status_code == 200:
    print("Form submitted successfully!")
    print(response.json())
else:
    print(f"Failed to submit the form. Status code: {response.status_code}")
# Out:
# Failed to submit the form. Status code: 401

# %%
#Full Address (office)

import requests

# URL and headers
url = 'https://api.startupindia.gov.in/sih/api/auth/dpiit/services/application/save'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Content-Type': 'application/json',
    'X-Auth-Token': 'eyJhbGciOiJIUzUxMiIsInppcCI6IkRFRiJ9.eNp8jjsOwjAQRO-yNYoSx3HsVJyAhhJRrJ2NMApx5A9Cirg7i6CgopzZN6u3wTV7GEBJ2zVG9SRt7aTUirTqlSDYAZaRgUOIN5w5pmI53jEmrHwSzd7ekqMKXeUXPnvMMDRKG63attc7oMf6KUytundREkUYNliLnX26EH_PsRBPl7GkHD0lGE7QTVI76iaBxlqeunHCpm9rOLMDuRziH8yINzYHh9mHhX2_mPnBzGTFyMYxzMTEMWPMZYXn8wUAAP__.gnPJMnCi3DkdKbNf7ggZa7ZkexIWYNG6M58g-LvRBeLYetV2oAzpAAFRk70GM9hCIDk7V0cXsfP_7W3CTB3aVg'
}

# Updated Payload data
payload = {
    "incorporationNumber": "U62092MP2023PTC065665",
    "startupEntity": {
        "startupNatureOfEntity": {"id": "5f48ce5f2a9bb065cdfa185b"},
        "startupIndustry": {"id": "5f48ce5f2a9bb065cdfa1730"},
        "startupSection": {"id": "5f48ce5f2a9bb065cdfa1791"},
        "startupServices": [{"id": "5f48ce5f2a9bb065cdfa1856"}],
        "name": "HAXSPLOIT SECURITY SERVICES PRIVATE LIMITED",
        "incorporationDate": "2023-05-09",
        "panNumber": "AALCB0603L"
    },
    "recognitionDetailType": "ADDRESS",
    "status": "DRAFT",
    "address": {
        "address1": "BMS Hostel",
        "address2": "BMSCE",
        "address3": "Birgunj",
        "city": "Bangalore",
        "stateId": "5f48ce592a9bb065cdf9fb2d",
        "stateName": "Karnataka",
        "pinCode": "560009",
        "districtId": "5f48ce5a2a9bb065cdf9fd5a",
        "districtName": "Dharwad",
        "subDistrictId": "5f899c436133404801510a97",
        "subDistrictName": "Hubballi"
    }
}

# Make the POST request
response = requests.post(url, headers=headers, json=payload)

# Check the response
if response.status_code == 200:
    print("Form submitted successfully!")
    print(response.json())
else:
    print(f"Failed to submit the form. Status code: {response.status_code}")
# Out:
# Failed to submit the form. Status code: 401

# %%
import requests

# URL and headers
url = 'https://api.startupindia.gov.in/sih/api/auth/dpiit/services/application/save'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Content-Type': 'application/json',
    'X-Auth-Token': 'eyJhbGciOiJIUzUxMiIsInppcCI6IkRFRiJ9.eNp8jjsOwjAQRO-yNYoSx3HsVJyAhhJRrJ2NMApx5A9Cirg7i6CgopzZN6u3wTV7GEBJ2zVG9SRt7aTUirTqlSDYAZaRgUOIN5w5pmI53jEmrHwSzd7ekqMKXeUXPnvMMDRKG63attc7oMf6KUytundREkUYNliLnX26EH_PsRBPl7GkHD0lGE7QTVI76iaBxlqeunHCpm9rOLMDuRziH8yINzYHh9mHhX2_mPnBzGTFyMYxzMTEMWPMZYXn8wUAAP__.gnPJMnCi3DkdKbNf7ggZa7ZkexIWYNG6M58g-LvRBeLYetV2oAzpAAFRk70GM9hCIDk7V0cXsfP_7W3CTB3aVg'
}

# Updated Payload data
payload = {
    "incorporationNumber": "U62092MP2023PTC065665",
    "startupEntity": {
        "startupNatureOfEntity": {"id": "5f48ce5f2a9bb065cdfa185b"},
        "startupIndustry": {"id": "5f48ce5f2a9bb065cdfa1730"},
        "startupSection": {"id": "5f48ce5f2a9bb065cdfa1791"},
        "startupServices": [{"id": "5f48ce5f2a9bb065cdfa1856"}],
        "name": "HAXSPLOIT SECURITY SERVICES PRIVATE LIMITED",
        "incorporationDate": "2023-05-09",
        "panNumber": "AALCB0603L"
    },
    "recognitionDetailType": "INFORMATION",
    "status": "DRAFT",
    "address": {
        "address1": "BMS Hostel",
        "address2": "BMSCE",
        "address3": "Birgunj",
        "city": "Bangalore",
        "stateId": "5f48ce592a9bb065cdf9fb2d",
        "stateName": "Karnataka",
        "pinCode": "560009",
        "districtId": "5f48ce5a2a9bb065cdf9fd5a",
        "districtName": "Dharwad",
        "subDistrictId": "5f899c436133404801510a97",
        "subDistrictName": "Hubballi"
    },
    "representative": {
        "name": "ram",
        "designation": "cto",
        "mobile": "9153229624",
        "email": "varsa@gmail.com"
    },
    "directors": [
        {
            "directorCin": "12345678",
            "name": "varsa",
            "gender": "FEMALE",
            "mobilePrefix": "+91",
            "mobileNumber": "9153229876",
            "address": "bms hostel",
            "email": "varsgupta07a@gmail.com"
        },
        {
            "directorCin": "98765432",
            "name": "aaisha",
            "gender": "FEMALE",
            "mobilePrefix": "+91",
            "mobileNumber": "9812227654",
            "address": "bms hostel",
            "email": "varsa.is21@gmail.com"
        }
    ],
    "activities": {
        "problemStatement": "rfrf frtrtt swded\ner klrkfrf rmfrc\nTo automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip: To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip: To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:",
        "problemSolution": "frrcfr jfnrcj  hjfrjf frr\nTo automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip: To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:",
        "solutionUniqueness": "wedhenj dedbhejrdbe djehr dfjerTo automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip: To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:",
        "generateRevenue": "To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:  To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:To automate the form-filling process and make a POST request with the given payload, you can use the requests library in Python. First, make sure you have the requests library installed. If not, you can install it using pip:\nderfr frfgtrgt derf refrfrgt"
    },
    "additionalInformation": {
        "numberOfEmployees": "5",
        "stage": "VALIDATION",
        "ipr": True,
        "workCategory": False,
        "scalableBusinessModel": True,
        "receiveFunding": False,
        "iprs": [
            {
                "applicationNumber": "76676",
                "iprTitle": "PATENT",
                "applied": False,
                "registered": True
            },
            {
                "applicationNumber": "3 ",
                "iprTitle": "TRADEMARK",
                "applied": True,
                "registered": False
            },
            {
                "applicationNumber": "333",
                "iprTitle": "COPYRIGHT",
                "applied": True,
                "registered": False
            },
            {
                "applicationNumber": "234 ",
                "iprTitle": "DESIGN",
                "applied": True,
                "registered": False
            },
            {
                "applicationNumber": "45",
                "iprTitle": "PLANT_VARIETY",
                "applied": False,
                "registered": True
            }
        ],
        "workCategories": [],
        "fundingProof": {},
        "businessModel": {
            "wealthCreation": True,
            "note": "medc dernmcn fe crerfcnk   rncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfc  nkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcn   krncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfc   nkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcn    krncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfc    nkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf \nmedc dernmcn fe crerfcnkrncfrne fckjfvncfv jkrfkrecfr frckmfcvnfkcf "
        }
    }
}

# Make the POST request
response = requests.post(url, headers=headers, json=payload)

# Check the response
if response.status_code == 200:
    print("Form submitted successfully!")
    print(response.json())
else:
    print(f"Failed to submit the form. Status code: {response.status_code}")
# Out:
# Failed to submit the form. Status code: 401
